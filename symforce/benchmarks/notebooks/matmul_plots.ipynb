# %%
import numpy as np
import matplotlib.pyplot as plt
from plotly import express as ex
import pandas as pd
import scipy.io
from pathlib import Path

# %%
matrices = []
for path in Path("matrices").iterdir():                                                                                                                                                                                                   
    matrix_name = path.name                                                                                                                                                                                                               
    for filename in filter(lambda p: p.suffix == ".mtx", path.iterdir()):                                                                                                                                                                 
        M = scipy.io.mmread(filename)                                                                                                                                                                                                     
        if M.shape[0] > 1 and M.shape[1] > 1:                                                                                                                                                                                             
            break                                                                                                                                                                                                                         
    else:                                                                                                                                                                                                                                 
        raise                                                                                                                                                                                                                             
    matrices.append((matrix_name.replace(" ", "").replace("-", "_"), filename, M))                                                                                                                                                        
                                                                                                                                                                                                                                          
matrices.sort(key=lambda m: m[2].nonzero()[0].size)
matrices = [m[0] for m in matrices]
gain = {m: (1 if i < 3 else 100) for i, m in enumerate(matrices)}

# %%
# d = {('b1_ss', 'double', 'sparse'): [1159.076521, 14719148954.0, 4617354287.0], ('b1_ss', 'double', 'flattened'): [290.518235, 3513781336.0, 1108941379.0], ('b1_ss', 'double', 'dense_dynamic'): [457.628629, 5764071771.0, 1391030064.0], ('b1_ss', 'double', 'dense_fixed'): [144.751511, 1407516812.0, 565861618.0], ('b1_ss', 'float', 'sparse'): [1118.066682, 14037436561.0, 4497953125.0], ('b1_ss', 'float', 'flattened'): [278.348846, 3248175770.0, 1041572109.0], ('b1_ss', 'float', 'dense_dynamic'): [496.10802, 5998506314.0, 1475673389.0], ('b1_ss', 'float', 'dense_fixed'): [149.660393, 1324020896.0, 516525523.0], ('Tina_DisCog', 'double', 'sparse'): [2976.037026, 38107069307.0, 12505186276.0], ('Tina_DisCog', 'double', 'flattened'): [883.928213, 10875202814.0, 3530590287.0], ('Tina_DisCog', 'double', 'dense_dynamic'): [666.062875, 8390176032.0, 2238578116.0], ('Tina_DisCog', 'double', 'dense_fixed'): [504.201971, 6506822763.0, 1938470629.0], ('Tina_DisCog', 'float', 'sparse'): [2762.464362, 36390977061.0, 12128525825.0], ('Tina_DisCog', 'float', 'flattened'): [748.157919, 9913468332.0, 3331156188.0], ('Tina_DisCog', 'float', 'dense_dynamic'): [570.220591, 7390984694.0, 1954008799.0], ('Tina_DisCog', 'float', 'dense_fixed'): [393.258338, 5162756652.0, 1503940831.0], ('n3c4_b2', 'double', 'sparse'): [3435.931642, 44208468718.0, 14766847725.0], ('n3c4_b2', 'double', 'flattened'): [1000.092774, 12176917268.0, 4149928466.0], ('n3c4_b2', 'double', 'dense_dynamic'): [944.430619, 11566538669.0, 3112642941.0], ('n3c4_b2', 'double', 'dense_fixed'): [711.795105, 9123211700.0, 2633543827.0], ('n3c4_b2', 'float', 'sparse'): [3261.377758, 43092309627.0, 14616194959.0], ('n3c4_b2', 'float', 'flattened'): [893.909927, 11518804398.0, 4024213919.0], ('n3c4_b2', 'float', 'dense_dynamic'): [1089.091812, 13321440392.0, 3981711997.0], ('n3c4_b2', 'float', 'dense_fixed'): [858.462497, 11133036000.0, 3688589304.0]}
 36, 84, 3024, 252): [65.843983, 733343012.0, 311912384.0], ('bibd_9_3', 'double', 'dense_dynamic', 36, 84, 3024, 252): [131.876468, 1579313610.0, 514380660.0], ('bibd_9_3', 'double', 'dense_fixed', 36, 84, 3024, 252): [128.690005, 1482751252.0, 505146003.0], ('lp_sc105', 'double', 'sparse', 105, 163, 17115, 340): [159.657506, 1918261062.0, 739866228.0], ('lp_sc105', 'double', 'flattened', 105, 163, 17115, 340): [40.520398, 460701824.0, 196825221.0], ('lp_sc105', 'double', 'dense_dynamic', 105, 163, 17115, 340): [2074.208572, 18162980911.0, 6383131613.0], ('lp_sc105', 'double', 'dense_fixed', 105, 163, 17115, 340): None}

# %%
d = {k: v for k, v in d.items() if v is not None}

def remap(s):
    return {
        "sparse": "Sparse",
        "dense_dynamic": "Dense Dynamic",
        "dense_fixed": "Dense Fixed",
        "flattened": "SymForce"
    }[s]
d = {k: [x * gain[k[0]] for x in v] for k, v in d.items()}

SCALE_WORST = True
if SCALE_WORST:
    d = {k: [x / worst_cpu[k[0]] for x in v] for k, v in d.items()}
d = {(k[0], k[1], remap(k[2]), k[3], k[4], k[5], k[6]): v for k, v in d.items()}
d
# Out:
# {('b1_ss', 'double', 'Sparse', 7, 7, 49, 15): [1.0,
#   13095506.43631677,
#   4078404.1547849537],
#  ('b1_ss', 'double', 'SymForce', 7, 7, 49, 15): [0.008222403259831848,
#   81786.30729008807,
#   16414.378459929325],
#  ('b1_ss', 'double', 'Dense Dynamic', 7, 7, 49, 15): [0.3341318972943764,
#   4617523.143527931,
#   1123360.2063706154],
#  ('b1_ss', 'double', 'Dense Fixed', 7, 7, 49, 15): [0.06136422339862517,
#   611375.7749034084,
#   377556.8937107628],
#  ('Tina_DisCog', 'double', 'Sparse', 11, 11, 121, 48): [1.0,
#   13082668.582515044,
#   4251293.409858722],
#  ('Tina_DisCog', 'double', 'SymForce', 11, 11, 121, 48): [0.011613813103965358,
#   165479.2114093807,
#   38039.57009915331],
#  ('Tina_DisCog',
#   'double',
#   'Dense Dynamic',
#   11,
#   11,
#   121,
#   48): [0.17453577321947436, 2353194.204895724, 634538.7916145364],
#  ('Tina_DisCog',
#   'double',
#   'Dense Fixed',
#   11,
#   11,
#   121,
# ...

# %%
df = pd.DataFrame([key + tuple(value) for key, value in d.items()], columns=("mat", "scalar", "test", "M", "N", "MN", "nnz", "cpu", "instr", "l1-load"))
df
# Out:
#             mat  scalar           test    M    N     MN  nnz       cpu  \
# 0         b1_ss  double         Sparse    7    7     49   15  1.000000
# 1         b1_ss  double       SymForce    7    7     49   15  0.008222
# 2         b1_ss  double  Dense Dynamic    7    7     49   15  0.334132
# 3         b1_ss  double    Dense Fixed    7    7     49   15  0.061364
# 4   Tina_DisCog  double         Sparse   11   11    121   48  1.000000
# 5   Tina_DisCog  double       SymForce   11   11    121   48  0.011614
# 6   Tina_DisCog  double  Dense Dynamic   11   11    121   48  0.174536
# 7   Tina_DisCog  double    Dense Fixed   11   11    121   48  0.120748
# 8       n3c4_b2  double         Sparse   20   15    300   60  1.000000
# 9       n3c4_b2  double       SymForce   20   15    300   60  0.014465
# 10      n3c4_b2  double  Dense Dynamic   20   15    300   60  0.241660
# 11      n3c4_b2  double    Dense Fixed   20   15    300   60  0.166005
# ...

# %%
fig = ex.bar(df[df.scalar == "double"], x="mat", y="cpu", color="test", barmode="group",
       labels={"test": "Method", "mat": "Matrix", "cpu": "Relative CPU %"},
       category_orders={"test": ["Sparse", "Dense Dynamic", "Dense Fixed", "SymForce"]})
fig.update_layout(
    yaxis = dict(
        tickmode = 'array',
        tickvals = [0, 0.5, 1.0],
        ticktext = ['0%', "50%", "100%"]
    ),
    xaxis = dict(
        tickmode = 'array',
        tickvals = [0, 1, 2, 3, 4],
        ticktext = ['(a)', '(b)', '(c)', '(d)', '(e)']
    )

)
fig.show()
# Out:
# <div>                            <div id="5c9f694a-529e-4534-9e5a-d3a758df54e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c9f694a-529e-4534-9e5a-d3a758df54e7")) {                    Plotly.newPlot(                        "5c9f694a-529e-4534-9e5a-d3a758df54e7",                        [{"alignmentgroup":"True","hovertemplate":"Method=Sparse<br>Matrix=%{x}<br>Relative CPU %=%{y}<extra></extra>","legendgroup":"Sparse","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sparse","offsetgroup":"Sparse","orientation":"v","showlegend":true,"textposition":"auto","x":["b1_ss","Tina_DisCog","n3c4_b2","bibd_9_3","lp_sc105"],"xaxis":"x","y":[1.0,1.0,1.0,1.0,0.07697273463972552],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Met
# ...

# %%
tests = df[df.scalar == "double"].test.unique()

best_cpu = {}
worst_cpu = {}
shapes = []
for matrix in matrices[:5]:
    cs = []
    for test in tests:
        try:
            cpu = df.cpu[(df.scalar == 'double') & (df.mat == matrix) & (df.test == test)].values[0]
        except IndexError:
            cpu = "N/A"
        cs.append(cpu)
    best_cpu[matrix] = min([c for c in cs if not isinstance(c, str)])
    worst_cpu[matrix] = max([c for c in cs if not isinstance(c, str)])
    
    M = df.M[(df.mat == matrix)].values[0]
    N = df.N[(df.mat == matrix)].values[0]
    nnz = df.nnz[(df.mat == matrix)].values[0]
    shape = f"{M}x{N}, {round(nnz / (M * N) * 100)}\\%"
    shapes.append(shape)


print("& " + " & ".join(matrices[:5]).replace("_", "\\_") + " \\\\")
print("& " + " & ".join(shapes) + " \\\\ \\hline")
for test in tests:
    s = [test.replace("_", " ").title()]
    for matrix in matrices[:5]:
        try:
            cpu = df.cpu[(df.scalar == 'double') & (df.mat == matrix) & (df.test == test)].values[0]
        except IndexError:
            cpu = "N/A"
        s.append(cpu)
    def format(c):
        if c in best_cpu.values():
            c = round(c, 2)
            return f"\\textbf{{{c}}}"
        else:
            if isinstance(c, str):
                return c
            c = round(c, 2)
            return f"{c}"
    s = [format(c) for c in s]
    print(" & ".join(s) + " \\\\")
# Out:
# & b1\_ss & Tina\_DisCog & n3c4\_b2 & bibd\_9\_3 & lp\_sc105 \\
# & 7x7, 31\% & 11x11, 40\% & 20x15, 20\% & 36x84, 8\% & 105x163, 2\% \\ \hline
# Sparse & 1.0 & 1.0 & 1.0 & 1.0 & 0.08 \\
# Symforce & \textbf{0.01} & \textbf{0.01} & \textbf{0.01} & \textbf{0.31} & \textbf{0.02} \\
# Dense Dynamic & 0.33 & 0.17 & 0.24 & 0.61 & 1.0 \\
# Dense Fixed & 0.06 & 0.12 & 0.17 & 0.6 & N/A \\
